# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalpesh-Nandedkar/HEALTH-INSURANCE-CROSS-SELL-PREDICTION/blob/main/HEALTH_INSURANCE_CROSS_SELL_PREDICTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **Health Insurance Cross Sell Prediction**

# %% [markdown]
# ##### **Project Type**    - Classification
# ##### **Contribution**    - Individual
# ##### **Name**            - Kalpesh Nandedkar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Our client is an Insurance company which has provided Health Insurance to its customers now they need your help in building a model to predict whether the policyholders from the past year will also be interested in Vehicle Insurance provided by the company. An insurance policy is an arrangement by which a company undertakes to provide a guarantee of compensation for specified loss, damage, illness or death in return for the payment of a specified premium. A premium is a sum of money that the customer needs to pay regularly to an insurance company for this guarantee.
#
# Just like medical insurance, there is vehicle insurance where every year customer needs to pay a premium of certain amount to insurance provider company so that in case of any unfortunate accident by the vehicle, the insurance provider company will provide a compensation to the customer.
#
# 1. Data Wrangling
#   * Getting the data
#   * Understanding the variables
#   * Treating the missing values and outliers
#
# 2. Exploratory Data Analysis
#   * Checking the distribution of response variable
#   * Checking the distribution of independent variables
#   * Checking feature-wise responses
#   * Checking correlation among variables
#
# 3. Data Pre-processing
#   * Encoding the Categorical Variables
#   * Data splitting and handling class imbalance
#
#
# 4. Classification Algorithms and Implementation :
#   1. Logistic regression
#
#   2. Random Forest Classifier
#
#   3. XGBoost Classifier

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Kalpesh-Nandedkar/HEALTH-INSURANCE-CROSS-SELL-PREDICTION

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Our client is an Insurance company that has provided Health Insurance to its customers now they need your help in building a model to predict whether the policyholders (customers) from past year will also be interested in Vehicle Insurance provided by the company.
#
# An insurance policy is an arrangement by which a company undertakes to provide a guarantee of compensation for specified loss, damage, illness, or death in return for the payment of a specified premium. A premium is a sum of money that the customer needs to pay regularly to an insurance company for this guarantee.
#
# For example, you may pay a premium of Rs. 5000 each year for a health insurance cover of Rs. 200,000/- so that if, God forbid, you fall ill and need to be hospitalised in that year, the insurance provider company will bear the cost of hospitalisation etc. for upto Rs. 200,000. Now if you are wondering how can company bear such high hospitalisation cost when it charges a premium of only Rs. 5000/-, that is where the concept of probabilities comes in picture. For example, like you, there may be 100 customers who would be paying a premium of Rs. 5000 every year, but only a few of them (say 2-3) would get hospitalised that year and not everyone. This way everyone shares the risk of everyone else.
#
# Just like medical insurance, there is vehicle insurance where every year customer needs to pay a premium of certain amount to insurance provider company so that in case of unfortunate accident by the vehicle, the insurance provider company will provide a compensation (called ‘sum assured’) to the customer.
#
# Building a model to predict whether a customer would be interested in Vehicle Insurance is extremely helpful for the company because it can then accordingly plan its communication strategy to reach out to those customers and optimise its business model and revenue.
#
# Now, in order to predict, whether the customer would be interested in Vehicle insurance, you have information about demographics (gender, age, region code type), Vehicles (Vehicle Age, Damage), Policy (Premium, sourcing channel) etc.

# %% [markdown]
# ![Health insurance.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Attribute Information**

# %% [markdown]
# 1. id :	Unique ID for the customer
#
# 2. Gender	: Gender of the customer
#
# 3. Age :	Age of the customer
#
# 4. Driving_License	0 : Customer does not have DL, 1 : Customer already has DL
#
# 5. Region_Code :	Unique code for the region of the customer
#
# 6. Previously_Insured	: 1 : Customer already has Vehicle Insurance, 0 : Customer doesn't have Vehicle Insurance
#
# 7. Vehicle_Age :	Age of the Vehicle
#
# 8. Vehicle_Damage	 :1 : Customer got his/her vehicle damaged in the past. 0 : Customer didn't get his/her vehicle damaged in the past.
#
# 9. Annual_Premium	: The amount customer needs to pay as premium in the year
#
# 10. PolicySalesChannel :	Anonymized Code for the channel of outreaching to the customer ie. Different Agents, Over Mail, Over Phone, In Person, etc.
#
# 11. Vintage :	Number of Days, Customer has been associated with the company
#
# 12. Response :	1 : Customer is interested, 0 : Customer is not interested

# %% [markdown]
# ## **A Quick overview of our strategy:**
# This project is divided into multiple sections and each section will have its own importance to our problem statement. the approach that we will be following in this project is given as-
#
# Section 1: Data overview: In this section, we will be importing important libraries and simply loading our dataset into google collab and will explore the basic information about the data.
#
# Section 2: Exploratory Data Analysis: In this section, We will focus on Exploratory data analysis of the dataset using various methods and visualization plots and will be extracting the information from this dataset as much as we can.
#
# Section 3: Outliers handling: In this section, we will be dealing with outliers in our dataset and will see how to define our outlier criteria and deal with outliers.
#
# Section 4: Feature Engineering: In this Section, we will be splitting the data into training and testing datasets then we will be scaling the data.
# Section 6: Model implementation: In this section, we will be applying and evaluating the ML models to predict the results.
#
# Section 7: Model Explainability: In this section, we will use model explainability to explain the results.
#
# Section 8: In this section, we will be giving a quick summary of the entire notebook.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Importing important libraries
# Tables and Data manipulations
import pandas as pd
import numpy as np

# Plotting & Data Visualization 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 

# To disable the display of all warning messages.
import warnings
warnings.filterwarnings('ignore')

# For balancing the ratio of data (handling imbalance class)
from imblearn.over_sampling import RandomOverSampler

# To find the best parameters to improve our model
from sklearn.model_selection import train_test_split , GridSearchCV, RandomizedSearchCV

# To evaluate the model's parameter
from sklearn.metrics import precision_score 
from sklearn.metrics import recall_score 
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report


#  To implement machine learning models and statistical modelling
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from collections import Counter
from imblearn.over_sampling import SMOTE

# %% [markdown]
# ### Dataset Loading

# %%
# Mounting Google Drive for Dataset loading
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Loading Dataset
dataset = pd.read_csv("/content/drive/MyDrive/AlmaBetter/Capstone Project/Capstone Project Supervised ML - Classification/TRAIN-HEALTH INSURANCE CROSS SELL PREDICTION.csv")

# %%
# creating a copy of the given data for further analysis
df = dataset.copy()

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (381109, 12)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print("Duplicate entry in df:",len(df[df.duplicated()]))
# Out:
# Duplicate entry in df: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# checking Percentage of Null Values present in each column
pd.options.display.float_format = '{:,.2f} %'.format
print((df.isnull().sum()/len(df))*100)
# Out:
# id                     0.00 %
# Gender                 0.00 %
# Age                    0.00 %
# Driving_License        0.00 %
# Region_Code            0.00 %
# Previously_Insured     0.00 %
# Vehicle_Age            0.00 %
# Vehicle_Damage         0.00 %
# Annual_Premium         0.00 %
# Policy_Sales_Channel   0.00 %
# Vintage                0.00 %
# Response               0.00 %
# dtype: float64

# %%
# Visualizing the missing values
plt.figure(figsize=(14, 5))
sns.heatmap(df.isnull(), cbar=True, yticklabels=False)
plt.xlabel("column_name", size=14, weight="bold")
plt.title("missing values in column",fontweight="bold",size=17)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * The dataset contains the information of the customers holding Health Insurance policy of an Insurance company. Now they need to build a model to predict whether the policyholders from the past year will also be interested in Vehicle Insurance provided by the company. With the help of this model the company can communicate efficiently to interested customers.
#
# * The dataset has 381109 rows and 12 columns. There are no missing values and duplicate values in the dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %%
# Dataset Describe
df.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_77bf4_row0_col0, #T_77bf4_row0_col1, #T_77bf4_row0_col2, #T_77bf4_row0_col3, #T_77bf4_row0_col4, #T_77bf4_row0_col6, #T_77bf4_row0_col7, #T_77bf4_row0_col8, #T_77bf4_row7_col0, #T_77bf4_row7_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_77bf4_row0_col5 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_77bf4_row1_col0, #T_77bf4_row5_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_77bf4_row1_col1, #T_77bf4_row1_col2, #T_77bf4_row1_col3, #T_77bf4_row1_col4, #T_77bf4_row1_col6, #T_77bf4_row1_col7, #T_77bf4_row1_col8, #T_77bf4_row2_col1, #T_77bf4_row2_col2, #T_77bf4_row2_col3, #T_77bf4_row2_col4, #T_77bf4_row2_col6, #T_77bf4_row2_col7, #T_77bf4_row2_col8, #T_77bf4_row3_col0, #T_77bf4_row3_col1, #T_77bf4_row3_col2, #T_77bf4_row3_col3, #T_77bf4_row3_col4, #T_77bf4_row3_col5, #T_77bf4_row3_col6, #T_77bf4_row3_col7, #T_77bf4_row3_col8, #T_77bf4_row4_col1, #T_77bf4_row4_col2, #T_77bf4_row4_col3, #T_77bf4_row4_col4, #T_77bf4_row4_col6, #T_77bf4_row4_col7, #T_77bf4_row4_col8, #T_77bf4_row5_col1, #T_77bf4_row5_col2, #T_77bf4_row5_col3, #T_77bf4_row5_col4, #T_77bf4_row5_col6, #T_77bf4_row5_col7, #T_77bf4_row5_col8, #T_77bf4_row6_col1, #T_77bf4_row6_col2, #T_77bf4_row6_col3, #T_77bf4_row6_col4, #T_77bf4_row6_col6, #T_77bf4_row6_col7, #T_77bf4_row6_col8, #T_77bf4_row7_col1, #T_77bf4_row7_col2, #T_77bf4_row7_col3, #T_77bf4_row7_col4, #T_77bf4_row7_col6, #T_77bf4_row7_col7, #T_77bf4_row7_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_77bf4_row1_col5, #T_77bf4_row5_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_77bf4_row2_col0 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_77bf4_row2_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_77bf4_row4_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_77bf4_row4_col5 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_77bf4_row6_col0 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_77bf4_row6_col5 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# </style>
# <table id="T_77bf4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77bf4_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_77bf4_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_77bf4_level0_col2" class="col_heading level0 col2" >Driving_License</th>
#       <th id="T_77bf4_level0_col3" class="col_heading level0 col3" >Region_Code</th>
#       <th id="T_77bf4_level0_col4" class="col_heading level0 col4" >Previously_Insured</th>
#       <th id="T_77bf4_level0_col5" class="col_heading level0 col5" >Annual_Premium</th>
#       <th id="T_77bf4_level0_col6" class="col_heading level0 col6" >Policy_Sales_Channel</th>
#       <th id="T_77bf4_level0_col7" class="col_heading level0 col7" >Vintage</th>
#       <th id="T_77bf4_level0_col8" class="col_heading level0 col8" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77bf4_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_77bf4_row0_col0" class="data row0 col0" >381109.000000</td>
#       <td id="T_77bf4_row0_col1" class="data row0 col1" >381109.000000</td>
#       <td id="T_77bf4_row0_col2" class="data row0 col2" >381109.000000</td>
#       <td id="T_77bf4_row0_col3" class="data row0 col3" >381109.000000</td>
#       <td id="T_77bf4_row0_col4" class="data row0 col4" >381109.000000</td>
#       <td id="T_77bf4_row0_col5" class="data row0 col5" >381109.000000</td>
#       <td id="T_77bf4_row0_col6" class="data row0 col6" >381109.000000</td>
#       <td id="T_77bf4_row0_col7" class="data row0 col7" >381109.000000</td>
#       <td id="T_77bf4_row0_col8" class="data row0 col8" >381109.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77bf4_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_77bf4_row1_col0" class="data row1 col0" >190555.000000</td>
#       <td id="T_77bf4_row1_col1" class="data row1 col1" >38.822584</td>
#       <td id="T_77bf4_row1_col2" class="data row1 col2" >0.997869</td>
#       <td id="T_77bf4_row1_col3" class="data row1 col3" >26.388807</td>
#       <td id="T_77bf4_row1_col4" class="data row1 col4" >0.458210</td>
#       <td id="T_77bf4_row1_col5" class="data row1 col5" >30564.389581</td>
#       <td id="T_77bf4_row1_col6" class="data row1 col6" >112.034295</td>
#       <td id="T_77bf4_row1_col7" class="data row1 col7" >154.347397</td>
#       <td id="T_77bf4_row1_col8" class="data row1 col8" >0.122563</td>
#     </tr>
#     <tr>
#       <th id="T_77bf4_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_77bf4_row2_col0" class="data row2 col0" >110016.836208</td>
#       <td id="T_77bf4_row2_col1" class="data row2 col1" >15.511611</td>
#       <td id="T_77bf4_row2_col2" class="data row2 col2" >0.046110</td>
#       <td id="T_77bf4_row2_col3" class="data row2 col3" >13.229888</td>
#       <td id="T_77bf4_row2_col4" class="data row2 col4" >0.498251</td>
#       <td id="T_77bf4_row2_col5" class="data row2 col5" >17213.155057</td>
#       <td id="T_77bf4_row2_col6" class="data row2 col6" >54.203995</td>
#       <td id="T_77bf4_row2_col7" class="data row2 col7" >83.671304</td>
#       <td id="T_77bf4_row2_col8" class="data row2 col8" >0.327936</td>
#     </tr>
#     <tr>
#       <th id="T_77bf4_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_77bf4_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_77bf4_row3_col1" class="data row3 col1" >20.000000</td>
#       <td id="T_77bf4_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_77bf4_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_77bf4_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_77bf4_row3_col5" class="data row3 col5" >2630.000000</td>
#       <td id="T_77bf4_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_77bf4_row3_col7" class="data row3 col7" >10.000000</td>
#       <td id="T_77bf4_row3_col8" class="data row3 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77bf4_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_77bf4_row4_col0" class="data row4 col0" >95278.000000</td>
#       <td id="T_77bf4_row4_col1" class="data row4 col1" >25.000000</td>
#       <td id="T_77bf4_row4_col2" class="data row4 col2" >1.000000</td>
#       <td id="T_77bf4_row4_col3" class="data row4 col3" >15.000000</td>
#       <td id="T_77bf4_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_77bf4_row4_col5" class="data row4 col5" >24405.000000</td>
#       <td id="T_77bf4_row4_col6" class="data row4 col6" >29.000000</td>
#       <td id="T_77bf4_row4_col7" class="data row4 col7" >82.000000</td>
#       <td id="T_77bf4_row4_col8" class="data row4 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77bf4_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_77bf4_row5_col0" class="data row5 col0" >190555.000000</td>
#       <td id="T_77bf4_row5_col1" class="data row5 col1" >36.000000</td>
#       <td id="T_77bf4_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_77bf4_row5_col3" class="data row5 col3" >28.000000</td>
#       <td id="T_77bf4_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_77bf4_row5_col5" class="data row5 col5" >31669.000000</td>
#       <td id="T_77bf4_row5_col6" class="data row5 col6" >133.000000</td>
#       <td id="T_77bf4_row5_col7" class="data row5 col7" >154.000000</td>
#       <td id="T_77bf4_row5_col8" class="data row5 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77bf4_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_77bf4_row6_col0" class="data row6 col0" >285832.000000</td>
#       <td id="T_77bf4_row6_col1" class="data row6 col1" >49.000000</td>
#       <td id="T_77bf4_row6_col2" class="data row6 col2" >1.000000</td>
#       <td id="T_77bf4_row6_col3" class="data row6 col3" >35.000000</td>
#       <td id="T_77bf4_row6_col4" class="data row6 col4" >1.000000</td>
#       <td id="T_77bf4_row6_col5" class="data row6 col5" >39400.000000</td>
#       <td id="T_77bf4_row6_col6" class=

# %% [markdown]
# ## <b> Variables Description </b>

# %% [markdown]
# ### <b> The dataset contains weather information ('id', 'Gender', 'Age', 'Driving_License', 'Region_Code','Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium','Policy_Sales_Channel', 'Vintage', 'Response')
# ### <b>Attribute Information: </b>
#  * ### id : Unique ID for the customer
#
#  * ### Gender : Gender of the customer
#
#  * ### Age : Age of the customer
#
# * ### Driving_License: 0 - Customer does not have DL, 1 - Customer already has DL
#
# * ### Region_Code : Unique code for the region of the customer
#
# * ### Previously_Insured : 1 - Customer already has Vehicle Insurance, 0 - Customer doesn't have Vehicle Insurance
#
# * ### Vehicle_Age : Age of the Vehicle
#
# * ### Vehicle_Damage :1 - Customer got his/her vehicle damaged in the past. 0 - Customer didn't get his/her vehicle damaged in the past.
#
# * ### Annual_Premium : The amount customer needs to pay as premium in the year
#
# * ### PolicySalesChannel : Anonymized Code for the channel of outreaching to the customer ie. Different Agents, Over Mail, Over Phone, In Person, etc.
#
# * ### Vintage : Number of Days, Customer has been associated with the company
#
# * ### Response : 1 : Customer is interested, 0 : Customer is not interested

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
column = df.columns.to_list()
for i in column:
  print('The number of Unique Values in', i, 'are:', dataset[i].nunique())
# Out:
# The number of Unique Values in id are: 381109
# The number of Unique Values in Gender are: 2
# The number of Unique Values in Age are: 66
# The number of Unique Values in Driving_License are: 2
# The number of Unique Values in Region_Code are: 53
# The number of Unique Values in Previously_Insured are: 2
# The number of Unique Values in Vehicle_Age are: 3
# The number of Unique Values in Vehicle_Damage are: 2
# The number of Unique Values in Annual_Premium are: 48838
# The number of Unique Values in Policy_Sales_Channel are: 155
# The number of Unique Values in Vintage are: 290
# The number of Unique Values in Response are: 2

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Creating Empty Variables for storing categorial & continuous variable
categorical_variable=[]
continous_variable=[]

# Dropping 'Id' column & Separating the categorical and continous variable and storing them
for i in df.columns:
  if i == 'id':
    pass
  elif df[i].nunique() <5:
    categorical_variable.append(i)
  elif df[i].nunique() >= 5:
    continous_variable.append(i)

# Printing categorial & continuous variable 
print(f"Categorical Variables :-",categorical_variable)
print(f"Continous Variables :-",continous_variable)
# Out:
# Categorical Variables :- ['Gender', 'Driving_License', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Response']
# Continous Variables :- ['Age', 'Region_Code', 'Annual_Premium', 'Policy_Sales_Channel', 'Vintage']

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# * The 'id' column did not convey any information so we removed it first.
# * We created two variables - categorial & continuous variables.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Target variable

# %%
# Chart - 1 visualization code

# setting the dimension for plots
fig, axes = plt.subplots(ncols=2,figsize=(18,5))

# creating count plot for season
sns.countplot(x = df['Response'],palette = 'viridis', data= df ,ax = axes[0])
# Title for count plot
plt.title('count for each Response', fontsize=13)

# Plotting Pie plot to check the Response distribution percent wise
df['Response'].value_counts().plot.pie( subplots=True, pctdistance=0.5,autopct='%0.0f%%', explode = [0.04,0.04],startangle = 65, cmap = 'Accent', ax = axes[1],figsize=(15,7))

# drawing circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
fig.tight_layout()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * We choose the pie chart as it represents the Response and Count of each part of the data to a whole where the arc size of each slice is directly proportional to the contribution of that part

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We see that 87.7% of no and 12.3% yes in Response for count.
#
# * We see that aprox 33000 and 4000 of count and 0 and 1 in response.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Later we will see if their is any impact of Response on health insueranc.

# %% [markdown]
# #### Chart - 2 Analysis on Gender

# %%
# Chart - 2 visualization code
# Exploring Gender using pie plot and barplot

# creating two figures in a row for the visualization
fig , axes  = plt.subplots(1,2,figsize = (10,6 ))

# Plotting Pie plot to check the gender distribution percent wise
df['Gender'].value_counts().plot.pie( autopct = '%.1f%%', explode = [0.04,0.04], startangle = 110, cmap = 'Paired_r', ax = axes[0])
axes[0].set_title('Percentage of each gender')

# plotting count plot for gender
sns.countplot(data = df , x = 'Gender', palette = 'Paired', ax =  axes[1])
axes[1].set_title('count for each gender')


plt.tight_layout()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * We choose the pie chart as it represents the Gender and Count of each part of the data to a whole where the arc size of each slice is directly proportional to the contribution of that part

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We see that 54.1% of Male and 45.9% Female in gender for count.
#
# * We see that aprox 20000 of Male and 17500 in female.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Later we will see if their is any impact of Gender on count.

# %% [markdown]
# #### Chart - 3 Age

# %%
# Chart - 3 visualization code
# understanding the Age feature distribution and it's effect on success/failure of insurance conversion 

# Defining the figure using subplots for two plots in one row
fig, axes = plt.subplots( 1,2 , figsize = (12,6))

# plotting distplot for Age column
sns.distplot( x= df['Age'], color= 'g', ax =axes[0])
axes[0].set_title('Age distribution')
axes[0].set_xlabel('Age')

# plotting distplot for Age and analyzing the effect on success/failure of insurance conversion
sns.distplot( x= df['Age'], color= 'r', ax =axes[1])
sns.distplot( x= df.Age[df['Response'] == 1], color= 'b', ax =axes[1])
axes[1].set_title('Age distribution Vs Response')
axes[1].set_xlabel('Age')

plt.show()
plt.tight_layout()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * We picked this chart as it shows whether the observations are high or low and also whether they are concentrated in one area or spread out across the entire scale for continous features only

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Avarage Age Distribution value is under 0.8 and graph is rightly skewed, which shows most of the age are density.
#
# 2. We can clearly observe that most of the age have their aprox 85 to 80.
#
# 3. Avarage number of age 90.

# %% [markdown]
# #### Chart - 4  **Region code**

# %%
# checking for numerically max value for region code
df['Region_Code'].max()
# Out:
# 52.0

# %%
# Chart - 4 visualization code
# Analyzing region code feature and it's effect on response feature

# defining the figure for visualization
plt.figure(figsize = (15,5))

# no. of ticks on plot along x Axis
ticks = list(range(1,53))

# converting the datatype from flaot to int
df['Region_Code'] = df['Region_Code'].astype(int) 

# Plotting the reason code and it's effect on response in same plot
sns.histplot( x= df['Region_Code'], color = 'c', bins =52)
sns.histplot( x= df['Region_Code'][df['Response'] ==1 ],  color = 'r', bins =52)

plt.ylim(0,6000)
plt.xticks(ticks)
plt.title('Region Code Vs response')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To see since how many count the Region code have been insurance .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * In this countplot, we can see that 1 has the greatest count . 1 indicates the region code are not participating in insurance and rest all count indicate the numbers of count of insurance , since how many week they have been participating in health.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * From above graph we can infer that many insurance are continuing participating in the region code which indicates the count are not meeting the required targets.

# %% [markdown]
# #### Chart - 5  **Vehicle age**

# %%
# Code to define a funtion to plot the pattern of responses corresponding to numerical columns
def response_for_features(col):
  ''' The function plots the Response classes
   for different classes in categorical variables'''
  plt.figure(figsize=(8,8))
  plt.subplot(2,1,1)
  sns.kdeplot(data=dataset, x=col,hue='Response')
  plt.title(f"{col}-wise responses",fontsize=20)
  plt.xlabel('Responses',fontsize=20)
  plt.ylabel(f"{col}Count",fontsize=20)
  plt.grid(True)
  plt.subplot(2,1,1)
  dataset.boxplot(column=col,by='Response',figsize=(5,5))

# %%
# Chart - 9 visualization code : Age-wise response
response_for_features('Age')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Kernel Density Estimation (KDE) is a way to estimate the probability density function of a continuous random variable. And a box plot is a plot of the distribution of a continuous variable based on the quartiles of the variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Younger population has higher frequency but it shows less interest in the insurance policy.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Middle-aged and even elder people are showing more interest in the vehicle insurance policy so the company should design its policies accordingly.

# %% [markdown]
# #### Chart - 6 **Vehicle damage**

# %%
# To get the general idea of vehicle damage which are insured
pd.DataFrame(df.groupby('Vehicle_Damage')['Response'].sum())
pd.DataFrame(df['Vehicle_Damage'].value_counts())
# Out:
#      Vehicle_Damage
# Yes          192413
# No           188696

# %%
# Chart - 6 visualization code
# Analysis on Vehicle damage and effect on response
plt.figure(figsize= (6,5))
sns.histplot(data = df, x= 'Vehicle_Damage', hue= df['Response'], palette = 'CMRmap_r')
plt.title('Vehicle Damage VS Response')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * We used this plot to visualize the distribution of vehicle age in yes, no. Count plots can help us understand how the values of a variable are distributed within the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We see that vehicle damage yes and 1 of 5000 and no of 175000.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * The class of damaged vehicles is potential customer of the company.

# %% [markdown]
# #### Chart - 7 **Annual premium**

# %%
# Chart - 7 visualization code
# Analysis on Annual distribution along with response relation with annual premium

# defining figures
fig, axes = plt.subplots(2,1, figsize =( 12,12))

# plotting distplot for annual premium
sns.distplot( x= df['Annual_Premium'], ax = axes[0], bins = 100)
axes[0].set_title('Annual premium distribution')

# plotting hist plot and response distribution 
sns.histplot( x= df['Annual_Premium'], ax = axes[1], bins = 200, kde = True)
sns.histplot( x= df['Annual_Premium'][df['Response'] == 1], ax = axes[1], bins = 200, color = 'r', kde = True)
axes[1].set_xlim(0,200000)
axes[1].set_ylim(0,50000)
axes[1].set_title('Annual premium vs response')
# Out:
# Text(0.5, 1.0, 'Annual premium vs response')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * We picked this chart as it shows whether the observations are high or low and also whether they are annual premium in one area or spread out across the entire scale for continous features only.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Avarage annual premium Distribution value is under 5000 and graph is rightly skewed, which shows most of the age are density.
#
# 2. We can clearly observe that most of the age have their aprox 5000 to 200000.
#
# 3. Avarage number of age 100000.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * As we can see most of the annual premium are under 200000, to expand their business and sales they should open their count.

# %% [markdown]
# #### Chart - 8  **Policy sales channel**

# %%
# Chart - 8 visualization code
# converting the data type as int
df['Policy_Sales_Channel'] = df['Policy_Sales_Channel'].astype(int)

# plotting the relation between policy sales channel and responses
plt.figure(figsize = ( 10, 6))

# plotting the histogram plots for sales channel 
sns.histplot( x= df['Policy_Sales_Channel'], bins = 175)
sns.histplot( x= df['Policy_Sales_Channel'][df['Response'] == 1], bins = 175, color = 'r')

plt.ylim(0,50000)
plt.show()


# checking for the top 10 sales channel that produces the most no. of success 
sub_df1 = pd.DataFrame(df['Policy_Sales_Channel'].value_counts()).head(10).reset_index()
sub_df2 = pd.DataFrame(df.groupby('Policy_Sales_Channel')['Response'].sum()).reset_index()
sub_df2.rename(columns = {'Policy_Sales_Channel' : 'index'}, inplace = True)
top_channels = pd.merge(sub_df1 , sub_df2, on = 'index', how = 'left')
top_channels.rename(columns = {'index': 'Policy_Sales_Channel', 'Policy_Sales_Channel' : 'Counts', 'Response' : 'Response_1'  })
# Out:
#    Policy_Sales_Channel  Counts  Response_1
# 0                   152  134784        3858
# 1                    26   79700       15891
# 2                   124   73995       13996
# 3                   160   21779         475
# 4                   156   10661        2297
# 5                   122    9930        1720
# 6                   157    6684        1794
# 7                   154    5993        1474
# 8                   151    3885         122
# 9                   163    2893         880

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * We picked this chart as it shows whether the observations are high or low and also whether they are policy sale channel in one area or spread out across the entire scale for continous features only.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Avarage policy sale channel Distribution value is under 5000 and graph is rightly skewed, which shows most of the age are density.
#
# 2. We can clearly observe that most of the age have their aprox 0 to 160.
#
# 3. Avarage number of age 5000.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * As we can see most of the polict sale are under 5000, to expand their business and sales they should open their sale in posh area or where the upper class

# %% [markdown]
# #### Chart - 9   **VINTAGE**

# %%
# Chart - 9 visualization code
response_for_features('Vintage')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Kernel Density Estimation (KDE) is a way to estimate the probability density function of a continuous random variable. And a box plot is a plot of the distribution of a continuous variable based on the quartiles of the variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Responses are uniformally distributed over vintage range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * The gained insights do not help creating a positive business impact.

# %% [markdown]
# #### Chart - 10  **Previously Insured**

# %%
# To get the general idea of number of people who are previously insured
pd.DataFrame(df.groupby('Previously_Insured')['Response'].sum())
pd.DataFrame(df['Previously_Insured'].value_counts())
# Out:
#    Previously_Insured
# 0              206481
# 1              174628

# %%
# Chart - 10 visualization code
# Analysis on previously insured damage and effect on response
df['Previously_Insured'].astype(int)
plt.figure(figsize= (6,5))
sns.countplot(data = df, x= 'Previously_Insured', hue= df['Response'], palette = 'Paired')
plt.title('Previously_insured VS Response')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * We plotted above graph to know the distribution of different type of count,assortment,Previously insured in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Since there is significant diffference in the number of occurrence of different count types and assortments

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * As we can see that previously insured is highest is 0 to 1 and 0 to 175000 in number. So it's quite intersting to see weather these assortments and count will also get the heighest count in bivariate analysis also!!!

# %% [markdown]
# #### Chart - 11 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Plotting heatmap to look at the correlation of features
plt.figure(figsize = (10,8))
sns.heatmap(df.corr(), annot = True,  cmap = 'viridis')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A correlation matrix is a table showing correlation coefficients between variables. Each cell in the table shows the correlation between two variables. The range of correlation is [-1,1].
#
# * Thus to know the correlation between all the variables along with the correlation coeficients, i used correlation heatmap.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The correlation matrix showes no strong correlation among the variables. The dependent variable 'Response' also exhibits poor correlation with independent features.

# %% [markdown]
# #### Chart - 12 - Pair Plot

# %%
# Pair Plot visualization code
# plotting pairplot which will give overview of  all the numeric features and responses in 1 plot but surely
sns.pairplot(df[['Age', 'Annual_Premium', 'Policy_Sales_Channel', 'Vintage', 'Response']], hue= 'Response')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * It can give multiple visual aids in a single frame and various insights related to the data can be gained in one single look.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Pairplot helped us to visualize the relationship between health insurance and other variables, such as id, age , annual premium, and policy sale chanel Columns. This helped us to identify which variables might be useful for predicting sales and inform the design for our machine learning model.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# 1. There is a relationship between id and Annual_Premium.
# 2. There is a relationship between Policy_Sales_Channel and Vintage.
# 3. There is a relationship betweenPreviously_Insured and Driving_License.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null hypothesis - There is a relationship between id and Annual_Premium
#
# Alternate Hypothesis - There is no relationship between id and Annual_Premium

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import pearsonr
first_sample = df["id"].head(60)
second_sample = df["Annual_Premium"].head(60)

stat, p = pearsonr(first_sample, second_sample)
print('stat=%.3f, p = %.2f'%(stat, p))
if p> 0.05:
  print('Accept Null Hypothesis')
else:
  print('Rejected Null Hypothesis')
# Out:
# stat=-0.016, p = 0.90
# Accept Null Hypothesis

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# * We have used insurance Correlation test to obtain P-Value along with insurance Correlation coefficient value.It is a measure of linear correlation between two sets of data.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# * We want to check the relationship between two features if they are positively or negatively correlated.P-value and Pearson Correlation coefficient will always have a value between -1 and 1.Here we can see that after applying test on id we got Correlation coefficient as -0.016 which implies that theses two features are having strong positive correlation between them

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null hypothesis - There is a relationship between Policy_Sales_Channel and Vintage.
#
# Alternate Hypothesis - There is no relationship Policy_Sales_Channel and Vintage.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import pearsonr
first_sample = df["Policy_Sales_Channel"].head(60)
second_sample = df["Vintage"].head(60)

stat, p = pearsonr(first_sample, second_sample)
print('stat=%.3f, p = %.2f'%(stat, p))
if p> 0.05:
  print('Accept Null Hypothesis')
else:
  print('Rejected Null Hypothesis')
# Out:
# stat=-0.042, p = 0.75
# Accept Null Hypothesis

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# * We have used insurance Correlation test to obtain P-Value along with insurance Correlation coefficient value.It is a measure of linear correlation between two sets of data.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# * We want to check the relationship between two features if they are positively or negatively correlated.P-value and Pearson Correlation coefficient will always have a value between -1 and 1.Here we can see that after applying test on Policy_Sales_Channel we got Correlation coefficient as -0.042 which implies that theses two features are having strong positive correlation between them

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null hypothesis - There is a relationship between Previously_Insured and Driving_License.
#
# Alternate Hypothesis - There is no relationship Previously_Insured and Driving_License.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import pearsonr
first_sample = df["Previously_Insured"].head(60)
second_sample = df["Driving_License"].head(60)

stat, p = pearsonr(first_sample, second_sample)
print('stat=%.3f, p = %.2f'%(stat, p))
if p> 0.05:
  print('Accept Null Hypothesis')
else:
  print('Rejected Null Hypothesis')
# Out:
# stat=nan, p = nan
# Rejected Null Hypothesis

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# * We have used insurance Correlation test to obtain P-Value along with insurance Correlation coefficient value.It is a measure of linear correlation between two sets of data.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# * We want to check the relationship between two features if they are positively or negatively correlated.P-value and Pearson Correlation coefficient will always have a value NAN.Here we can see that after applying test on DayOfWeek and sales features we got Correlation coefficient as NAN which implies that theses two features are having weak negative correlation between them.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
# checking for null values
df.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# * There is no Missing Values in this dataset.

# %% [markdown]
# ### 2. Handling Outliers

# %% [markdown]
# #Let's check outlier present in all numerical columns

# %%
# Plotting box plot for all numerical variable
plt.rcParams['figure.figsize']=(16,8)
ax =df[list(df.describe())].plot(kind='box', title='Boxplot', showmeans=True)
plt.show()

# %% [markdown]
# * From above we can see that 'Annual_Premium' variable has large amount of Outliers present in it, so I'll remove the outliers.
# * Other numerical columns have no outliers.

# %%
df['Annual_Premium'].describe()
# Out:
# count   381,109.00 %
# mean     30,564.39 %
# std      17,213.16 %
# min       2,630.00 %
# 25%      24,405.00 %
# 50%      31,669.00 %
# 75%      39,400.00 %
# max     540,165.00 %
# Name: Annual_Premium, dtype: float64

# %%
# Handling Outliers & Outlier treatments
plt.figure(figsize=(15,10))

plt.ylabel('Annual_Premium')
sns.boxplot(x=np.sqrt(df['Annual_Premium']))
plt.show()

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# * We use square root to reduce the scale of variable to prevent the loss of data.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
categorical_features= df.select_dtypes(include='object')

# %%
df.head(3)
# Out:
#    id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1   Male   44                1           28                   0
# 1   2   Male   76                1            3                   0
# 2   3   Male   47                1           28                   0
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes     40,454.00 %                    26      217
# 1    1-2 Year             No     33,536.00 %                    26      183
# 2   > 2 Years            Yes     38,294.00 %                    26       27
#
#    Response
# 0         1
# 1         0
# 2         1

# %% [markdown]
# # **Using label encoder**

# %%
# Initializing label encoder
le = LabelEncoder()
df = df.apply(le.fit_transform)
df.head(3)
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   0       1   24                1           28                   0
# 1   1       1   56                1            3                   0
# 2   2       1   27                1           28                   0
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0            2               1           23593                    24      207
# 1            0               0           16675                    24      173
# 2            2               1           21433                    24       17
#
#    Response
# 0         1
# 1         0
# 2         1

# %%
# Encode your categorical columns
df['Gender'] = pd.get_dummies(df['Gender'], drop_first=True)
df['Vehicle_Damage'] = pd.get_dummies(df['Vehicle_Damage'], drop_first=True)

# %%
#ploting Box plot to visualize and trying to get information from plot
for col in categorical_features:
  plt.figure(figsize=(8,6))
  sns.boxplot(x=df[col],y=df["Annual_Premium"])
  plt.show()

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# * I have used one-hot encoding technique to change our categorical features of object type into int type by creating their dummies so that it becomes compatible to feed it into various ML algorithms in future.
#
# * I have 0 to 500000 unique orderless categories in all the categorical features (which is less in number). So, it is good to use Nominal encoding technique than ordinal.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# creating a function to get df along with datatype , missing value no , unique values no , first value , second value

def DataInfoAll(df):
    print(f"Dataset Shape: {df.shape}")
    print("-"*75)
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.iloc[0].values
    summary['Second Value'] = df.iloc[1].values
    return summary

# %%
# Manipulate Features to minimize feature correlation and create new features
# Checking all the observation of the dataset we have to deal with.
DataInfoAll(df)
# Out:
# Dataset Shape: (381109, 12)
# ---------------------------------------------------------------------------
#                     Name dtypes  Missing  Uniques  First Value  Second Value
# 0                     id  int64        0   381109            0             1
# 1                 Gender  uint8        0        2            1             1
# 2                    Age  int64        0       66           24            56
# 3        Driving_License  int64        0        2            1             1
# 4            Region_Code  int64        0       53           28             3
# 5     Previously_Insured  int64        0        2            0             0
# 6            Vehicle_Age  int64        0        3            2             0
# 7         Vehicle_Damage  uint8        0        2            1             0
# 8         Annual_Premium  int64        0    48838        23593         16675
# 9   Policy_Sales_Channel  int64        0      155           24            24
# 10               Vintage  int64        0      290          207           173
# 11              Response  int64        0        2            1             0

# %% [markdown]
# #### 2. Feature Selection

# %%
# Plotting heatmap to look at the correlation of features
plt.figure(figsize = (14,12))
sns.heatmap(df.corr(), annot = True,  cmap = 'viridis')
plt.show()

# %% [markdown]
# #**Feature Selection**

# %%
# Building the model
from sklearn.ensemble import ExtraTreesClassifier
extra_tree_forest = ExtraTreesClassifier(n_estimators = 5,criterion ='entropy', max_features = 2)
a = df.drop(columns = ['id','Response'], axis = 1)
b = df['Response']

# Training the model
extra_tree_forest.fit(a, b)

# Computing the importance of each feature
feature_importance = extra_tree_forest.feature_importances_

# Normalizing the individual importances
feature_importance_normalized = np.std( [ tree.feature_importances_ for tree in extra_tree_forest.estimators_ ] , axis = 0)

# Plotting a Bar Graph to compare the models
plt.figure(figsize = (24,12))
plt.bar(a.columns, feature_importance_normalized)
plt.xlabel('Feature Labels' , fontsize = 25)
plt.ylabel('Feature Importances' , fontsize = 25)
plt.title('Comparison of different Feature Importances' , fontsize = 45)
# Out:
# Text(0.5, 1.0, 'Comparison of different Feature Importances')

# %%
# listing importance of every feature
feat_importances_Series = pd.Series( feature_importance_normalized , index=a.columns)
print("Feature Name\t\t Importance")
print("-"*37 , end='\n')
feat_importances_Series.sort_values()
# Out:
# Feature Name		 Importance
# -------------------------------------
# Driving_License        0.00 %
# Gender                 0.00 %
# Vehicle_Age            0.00 %
# Annual_Premium         0.01 %
# Policy_Sales_Channel   0.01 %
# Region_Code            0.01 %
# Vintage                0.01 %
# Age                    0.02 %
# Vehicle_Damage         0.03 %
# Previously_Insured     0.05 %
# dtype: float64

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# * The 'Driving_License' column is quasi constant but I am not going to drop it.
# The dataset does not have a lot of features so I am using all the features in the modeling.
# * I am going to drop 'id' column as it is not much used to us for modelling.

# %% [markdown]
# # DATA PREPROCESSING

# %%
# defining dependent and independent features
X = df.drop(columns = ['id','Response'], axis = 1)   # independent variable
y = df['Response']  # dependent variable

# %%
# Fill any numerical NaNs with mode()

fill_mode = lambda col: col.fillna(col.mode())
X = X.apply(fill_mode, axis=0)
df = df.apply(fill_mode, axis=0)

# %% [markdown]
# # Handling Imbalanced Dataset

# %%
# check for imbalance in data 
df['Response'].value_counts()
# Out:
# 0    334399
# 1     46710
# Name: Response, dtype: int64

# %% [markdown]
# * We can clearly see that there is a huge difference between the data set.
#
# * Standard ML techniques such as Decision Tree and Logistic Regression have a bias towards the majority class, and they tend to ignore the minority class. So solving this issue we use resampling technique.

# %%
# Oversampling the class for better modelling
ros = RandomOverSampler(random_state=0)
X_new,y_new= ros.fit_resample(X, y)

print("After Random Over Sampling Of Minor Class Total Samples are :", len(y_new))
print('Original dataset shape {}'.format(Counter(y)))
print('Resampled dataset shape {}'.format(Counter(y_new)))
# Out:
# After Random Over Sampling Of Minor Class Total Samples are : 668798
# Original dataset shape Counter({0: 334399, 1: 46710})
# Resampled dataset shape Counter({1: 334399, 0: 334399})

# %%
# plotting the above results
fig, axes = plt.subplots(1,2, figsize = (14,5))
oversampled = pd.concat([pd.DataFrame(y_new), pd.DataFrame(X_new)], axis=1)

sns.countplot(data = y, x = y, ax = axes[0], palette = 'viridis')
sns.countplot(data = oversampled, x = y_new, ax = axes[1], palette = 'viridis')
axes[0].set_title('Response count before oversampling')
axes[1].set_title('Response count after oversampling')
# Out:
# Text(0.5, 1.0, 'Response count after oversampling')

# %% [markdown]
# # Data Splitting

# %%
# performing train test split
from sklearn.model_selection import train_test_split

X_train , X_test, y_train, y_test = train_test_split(X_new, y_new, test_size=0.25, random_state = 42)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# * Here, I have used 75:25 split for train and test set. The given dataset has over 3 Lacs instances, so choosing split ratio is not that hard.

# %% [markdown]
# # DATA SCALLING

# %%
# Normalizing the Dataset using Standard Scaling Technique.
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# # **Model selection**
# #1. LOGISTIC REGRESSION
# #2. RANDOM FOREST
# #3. XGBClassifier

# %% [markdown]
# # ML Model - 1 - **LOGISTIC REGRESSION**

# %%
# ML Model - 1 Implementation

# Fit the Algorithm
log_model = LogisticRegression(fit_intercept=True, max_iter=10000)
log_model.fit(X_train, y_train)
# Predict on the model
# Get the predicted classes
log_test_class_preds = log_model.predict(X_test)
# Get the predicted probabilities
log_test_proba = log_model.predict_proba(X_test)[:,1]

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
# Evaluating Recall
recall_lgt = recall_score(y_test, log_test_class_preds)

# Evaluating Precision
precision_lgt = precision_score(y_test, log_test_class_preds)

# Evaluating  F1 Score
f1_lgt = f1_score(y_test, log_test_class_preds)

# Evaluating accuracy Score
accuracy_lgt = accuracy_score(log_test_class_preds, y_test)

# Evaluating AUC ROC SCore
acu_lgt = roc_auc_score(log_test_class_preds, y_test)

#print accuracy and Auc values of model
print("Accuracy : ",accuracy_lgt)
print("Precision:" ,precision_lgt)
print("Recall:" ,recall_lgt)
print("F1-Score:" ,f1_lgt)
print("ROC_AUC Score:" ,acu_lgt)

ind=["Accuracy : ","Precision:" ,"Recall:" ,"F1-Score:","ROC_AUC Score:"]
data={"Score":[accuracy_lgt,precision_lgt,recall_lgt,f1_lgt,acu_lgt]}
result=pd.DataFrame(data=data,index=ind)
result
# Out:
# Accuracy :  0.7860107655502392
# Precision: 0.7074337203257668
# Recall: 0.9759630900158971
# F1-Score: 0.8202809883314999
# ROC_AUC Score: 0.8342981656862515
#                 Score
# Accuracy :     0.79 %
# Precision:     0.71 %
# Recall:        0.98 %
# F1-Score:      0.82 %
# ROC_AUC Score: 0.83 %

# %%
# Getting classification Report
print(classification_report(log_test_class_preds,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.96      0.74     51780
#            1       0.98      0.71      0.82    115420
#
#     accuracy                           0.79    167200
#    macro avg       0.79      0.83      0.78    167200
# weighted avg       0.86      0.79      0.79    167200

# %% [markdown]
# **ROC curve for logistic reg.**

# %%
# Importing roc_curve library from sklearn
from sklearn.metrics import roc_curve

# Evaluating on the basis of roc curve
fpr, tpr, _ = roc_curve(y_test, log_test_proba)

# Plotting the curve
plt.figure( figsize = (4 ,4))
plt.title('Logistic Regression ROC curve')
plt.xlabel('FPR (Precision)')
plt.ylabel('TPR (Recall)')
plt.plot(fpr,tpr)
plt.plot((0,1), ls='dashed',color='black')
plt.show()

# %% [markdown]
# **Confusion Matrix for Logistic Reg.**

# %%
cm=confusion_matrix(y_test,log_test_class_preds)
print(cm)
plt.figure( figsize = (4 ,4))
sns.heatmap(cm,annot=True,cmap='BuPu')
# Out:
# [[49769 33768]
#  [ 2011 81652]]
# <Axes: >

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# instantiating Logistic Regression model
model2 = LogisticRegression(random_state = 42)

# Assigning certain Parameters for CV
log_params = { 'max_iter' : [80,100,120], 'l1_ratio': [0,0.1,0.5,0.8,1],}

# Implementing GridSearchCV
LR_grid  = GridSearchCV(model2, param_grid = log_params, cv = 10, scoring = 'roc_auc')

# Fit the Algorithm
LR_grid.fit(X_train, y_train)
# Getting optimal Parameters
LR_grid.best_estimator_
LR_optimal_model = LR_grid.best_estimator_
LR_grid.best_params_
# Out:
# {'l1_ratio': 0, 'max_iter': 80}

# %%
log_model = LogisticRegression(penalty = 'elasticnet',l1_ratio = 0, max_iter =80, solver = 'saga')
log_model.fit(X_train, y_train)

# Making predictions on test data
LR_test_preds = log_model.predict(X_test)

# Get the probabilities on test data
LR_test_proba = log_model.predict_proba(X_test)[:,1]

# %%
# Visualizing evaluation Metric Score chart
# Evaluating Recall
recall_lr = recall_score(y_test, LR_test_preds)

# Evaluating Precision
precision_lr = precision_score(y_test, LR_test_preds)

# Evaluating  F1 Score
f1_lr = f1_score(y_test, LR_test_preds)

# Evaluating accuracy Score
accuracy_lr = accuracy_score(LR_test_preds, y_test)

# Evaluating AUC ROC SCore
acu_lr = roc_auc_score(LR_test_preds, y_test)

#print accuracy and Auc values of model
print("Accuracy : ",accuracy_lr)
print("Precision:" ,precision_lr)
print("Recall:" ,recall_lr)
print("F1-Score:" ,f1_lr)
print("ROC_AUC Score:" ,acu_lr)
# Out:
# Accuracy :  0.7860107655502392
# Precision: 0.7074337203257668
# Recall: 0.9759630900158971
# F1-Score: 0.8202809883314999
# ROC_AUC Score: 0.8342981656862515

# %%
# Getting classification Report
print(classification_report(LR_test_preds,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.96      0.74     51780
#            1       0.98      0.71      0.82    115420
#
#     accuracy                           0.79    167200
#    macro avg       0.79      0.83      0.78    167200
# weighted avg       0.86      0.79      0.79    167200

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# * We have used GridSearchCV as the hyperparameter optimization technique as it uses all possible combinations of hyperparameters and provides the more accurate results. It then calculates the performance for each combination and selects the best value for the hyperparameters. This offers the most accurate tuning method.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# We have used different combinations of parameters to get the best value of auc_roc ,recall & precisiom for our case. The best combination was found out to be {'max_iter': 80, '11_ratio': 0} which doesn't resulted into the improvement in the macro avg from precision is 0.60 on the test set. Also weighted avg is remain same from recall to be 79% of the test dataset. At this point of time we have achieved above 78.60% accuracy by hyperparameter tuning of Logistic Regression.

# %% [markdown]
# # ML Model - 2 - **RANDOM FOREST**

# %%
# ML Model - 2 Implementation
# Implementing Random Forest
randomforest = RandomForestClassifier()
# Fitting the Algorithm
randomforest=randomforest.fit(X_train, y_train)

# Predict on the model
# Get the predicted classes
RF_pred = randomforest.predict(X_test)
# Get the predicted probabilities
RF_probability = randomforest.predict_proba(X_test)[:,1]

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
# Evaluating Recall
recall_RF = recall_score(y_test, RF_pred)

# Evaluating Precision
precision_RF = precision_score(y_test, RF_pred)

# Evaluating  F1 Score
f1_RF = f1_score(y_test, RF_pred)

# Evaluating accuracy Score
accuracy_RF = accuracy_score(RF_pred, y_test)

# Evaluating AUC ROC SCore
acu_RF = roc_auc_score(RF_pred, y_test)

#print accuracy and Auc values of model
print("Accuracy : ",accuracy_RF)
print("Precision:" ,precision_RF)
print("Recall:" ,recall_RF)
print("F1-Score:" ,f1_RF)
print("ROC_AUC Score:" ,acu_RF)

# Dataframing the data for better visualization
ind_RF =["Accuracy : ","Precision:" ,"Recall:" ,"F1-Score:","ROC_AUC Score:"]
data_RF ={"Score":[accuracy_RF,precision_RF,recall_RF,f1_RF,acu_RF]}
result_RF =pd.DataFrame(data=data_RF,index=ind_RF)
result_RF
# Out:
# Accuracy :  0.9452511961722488
# Precision: 0.9030432854067271
# Recall: 0.9977050787086287
# F1-Score: 0.9480169907323278
# ROC_AUC Score: 0.950237653777768
#                 Score
# Accuracy :     0.95 %
# Precision:     0.90 %
# Recall:        1.00 %
# F1-Score:      0.95 %
# ROC_AUC Score: 0.95 %

# %%
# printing classification report
print(classification_report(y_test,RF_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     83537
#            1       0.90      1.00      0.95     83663
#
#     accuracy                           0.95    167200
#    macro avg       0.95      0.95      0.95    167200
# weighted avg       0.95      0.95      0.95    167200

# %% [markdown]
# **ROC curve for Random Forest**

# %%
# Importing roc_curve library from sklearn
from sklearn.metrics import roc_curve

# Evaluating on the basis of roc curve
fpr, tpr, _ = roc_curve(y_test, RF_probability)

# Plotting the curve
plt.figure( figsize = (4 ,4))
plt.title('Random Forest ROC curve')
plt.xlabel('FPR (Precision)')
plt.ylabel('TPR (Recall)')
plt.plot(fpr,tpr)
plt.plot((0,1), ls='dashed',color='black')
plt.show()

# %% [markdown]
# **Confusion Matrix for Random Forest**

# %%
cm=confusion_matrix(y_test,RF_pred)
print(cm)
plt.figure( figsize = (4 ,4))
sns.heatmap(cm,annot=True,cmap='BuPu')
# Out:
# [[74575  8962]
#  [  192 83471]]
# <Axes: >

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# * There is an improvement in the macro avg from precision from 0.79 to 0.95 on the test set. Also weighted avg is further increased from recall from 0.79 to 0.95 and capturing variance more i.e of the test dataset. At this point of time we have achieved about 94.6% accuracy by RandomForest.

# %% [markdown]
# # ML Model - 3 **XGBoost Classifier**

# %%
# ML Model - 3 Implementation
# Implementing Random Forest
xgb=XGBClassifier()

# Fitting the Algorithm
XGB_fit=xgb.fit(X_train, y_train)

# Predict on the model
# Get the predicted classes
XGB_pred = XGB_fit.predict(X_test)
# Get the predicted probabilities
XGB_probability = XGB_fit.predict_proba(X_test)[:,1]

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
# Evaluating Recall
recall_XGB = recall_score(y_test, XGB_pred)

# Evaluating Precision
precision_XGB = precision_score(y_test, XGB_pred)

# Evaluating  F1 Score
f1_XGB = f1_score(y_test, XGB_pred)

# Evaluating accuracy Score
accuracy_XGB = accuracy_score(XGB_pred, y_test)

# Evaluating AUC ROC SCore
acu_XGB = roc_auc_score(XGB_pred, y_test)

#print accuracy and Auc values of model
print("Accuracy : ",accuracy_XGB)
print("Precision:" ,precision_XGB)
print("Recall:" ,recall_XGB)
print("F1-Score:" ,f1_XGB)
print("ROC_AUC Score:" ,acu_XGB)

# Dataframing the data for better visualization
ind_XGB =["Accuracy : ","Precision:" ,"Recall:" ,"F1-Score:","ROC_AUC Score:"]
data_XGB ={"Score":[accuracy_XGB,precision_XGB,recall_XGB,f1_XGB,acu_XGB]}
result_XGB =pd.DataFrame(data=data_XGB,index=ind_XGB)
result_XGB
# Out:
# Accuracy :  0.8138875598086125
# Precision: 0.75136097052267
# Recall: 0.9386825717461721
# F1-Score: 0.8346405645538408
# ROC_AUC Score: 0.8347576881522555
#                 Score
# Accuracy :     0.81 %
# Precision:     0.75 %
# Recall:        0.94 %
# F1-Score:      0.83 %
# ROC_AUC Score: 0.83 %

# %%
# printing classification report
print(classification_report(y_test,XGB_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.69      0.79     83537
#            1       0.75      0.94      0.83     83663
#
#     accuracy                           0.81    167200
#    macro avg       0.83      0.81      0.81    167200
# weighted avg       0.83      0.81      0.81    167200

# %% [markdown]
# **ROC curve for XGB Classifier**

# %%
# Importing roc_curve library from sklearn
from sklearn.metrics import roc_curve

# Evaluating on the basis of roc curve
fpr, tpr, _ = roc_curve(y_test, XGB_probability)

# Plotting the curve
plt.figure( figsize = (4 ,4))
plt.title('XGBClassifier ROC curve')
plt.xlabel('FPR (Precision)')
plt.ylabel('TPR (Recall)')
plt.plot(fpr,tpr)
plt.plot((0,1), ls='dashed',color='black')
plt.show()

# %% [markdown]
# **Confusion Matrix for XGB Classifier**

# %%
cm=confusion_matrix(y_test,XGB_pred)
print(cm)
plt.figure( figsize = (4 ,4))
sns.heatmap(cm,annot=True,cmap='BuPu')
# Out:
# [[57549 25988]
#  [ 5130 78533]]
# <Axes: >

# %% [markdown]
# #**Let's compare the models**

# %%
# Creating dataframe of Evaluation score Chart for Final Results of all the models
ind=['Logistic regression','RandomForest','XGBoost Classifier']
data={"Accuracy":[accuracy_lr,accuracy_RF,accuracy_XGB],"Recall":[recall_lr,recall_RF,recall_XGB],"Precision":[precision_lr,precision_RF,precision_XGB],
    'f1_score':[f1_lr,f1_RF,f1_XGB],"ROC_AUC":[acu_lr,acu_RF,acu_XGB]}
result=pd.DataFrame(data=data,index=ind)
result
# Out:
#                      Accuracy  Recall  Precision  f1_score  ROC_AUC
# Logistic regression    0.79 %  0.98 %     0.71 %    0.82 %   0.83 %
# RandomForest           0.95 %  1.00 %     0.90 %    0.95 %   0.95 %
# XGBoost Classifier     0.81 %  0.94 %     0.75 %    0.83 %   0.83 %

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# * **I am considering recall score here because False Negative is more important. The company should make the communications accordingly as the company would not like to miss a potential customer.**
#
# Recall: Recall, also known as sensitivity or true positive rate, is a metric that measures the proportion of true positive predictions among all instances that actually belong to the positive class. It is calculated by dividing the number of true positives by the sum of true positives and false negatives. A higher recall score indicates that the model has a lower rate of false negatives, which is important in applications where false negatives have a high cost.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# I have implemented 3 classification models:
#
# * Logistic Regression
# * Random Forest
# * XGBoost Classifier
#
# All the three models Logistic Regression, Random Forest and XGBClassifier are performing well. Based on the recall score(100%) Random Forest stands the best model it also has the highest accuracy of 95% in this situation it can be overfitted or just achive somewhat near optimal range.
#
# * So, on the basis of this XGBoost Classifier is the best fit for the given problem with recall at 94% & accuracy at 84%.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The ML model for the problem statement was created using python with the help of the dataset, and the ML model created with Random Forest and XGBoost Classifier models performed better than Logistics Regression model. Thus, for the given problem, the models created by Random Forest is preferred.
#
# 1. Customers of age between 30 to 60 are more likely to buy insurance.
# 2. Customers with Driving License have higher chance of buying Insurance.
# 3. Customers with Vehicle_Damage are likely to buy insurance.
# 4. The variable such as Previously_insured , Vehcile_Damage are more affecting the target variable.
# 5. The variable such as Driving_License , Gender are not affecting the target variable.
# 6. The previously not insured class is overwhelmingly opting for the policy.
# 7. The policy is not attracting younger customers. Elders are showing more interest.
# 8. A linear model is not that much effective however a tree based model come out to be a good model.
# 9. Previously Insured feature is most important feature in terms of predictions.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
